# %% [markdown]
# <a href="https://colab.research.google.com/github/RamandeepKBagri/tensorFlow/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#coursework: Introduction to deep learning #Cros entropy 
import matplotlib.pyplot as plt
import numpy as np

y = 0.2 
def lossCE(p,y):
  loss = -(y*np.log(p)+(1-y)*np.log(1-p))
  return loss

probabilities = np.arange(1e-3,0.999,1e-3)

loss = lossCE(probabilities,y)
plt.plot(probabilities,loss)
plt.title('Cross Entropy Loss')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = 0.4 
def lossCE(p,y):
  loss = -(y*np.log(p)+(1-y)*np.log(1-p))
  return loss

probabilities = np.arange(1e-3,0.999,1e-3)

loss = lossCE(probabilities,y)
plt.plot(probabilities,loss)
plt.title('Cross Entropy Loss')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = 0.5
def lossCE(p,y):
  loss = -(y*np.log(p)+(1-y)*np.log(1-p))
  return loss

probabilities = np.arange(1e-3,0.999,1e-3)

loss = lossCE(probabilities,y)
plt.plot(probabilities,loss)
plt.title('Cross Entropy Loss')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = 0.8
def lossCE(p,y):
  loss = -(y*np.log(p)+(1-y)*np.log(1-p))
  return loss

probabilities = np.arange(1e-3,0.999,1e-3)

loss = lossCE(probabilities,y)
plt.plot(probabilities,loss)
plt.title('Cross Entropy Loss')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = 1 
def lossCE(p,y):
  loss = -(y*np.log(p)+(1-y)*np.log(1-p))
  return loss

probabilities = np.arange(1e-3,0.999,1e-3)

loss = lossCE(probabilities,y)
plt.plot(probabilities,loss)
plt.title('Cross Entropy Loss')
plt.show()
